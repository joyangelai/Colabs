# %% [markdown]
# <a href="https://colab.research.google.com/github/joyangelai/Colabs/blob/main/cohort2_pandas1_tutorial_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
#Import pandas and numpy
import pandas as pd # for data manipulation and analysis
import numpy as np # used for mathematical computation # built on top of pandas

# %% [markdown]
# Data stractures used in pandas
# 1. pandas series
# 2. pandas data Frame

# %%
#Create a  num and str list and convert it to a series
a = ["car", "boat", "bike"] #list

series1 = pd.Series(a)
print(series1)
print(type(series1))
# Out:
# 0     car
# 1    boat
# 2    bike
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
#create a list and convert it to a dataframe
a = [("car", 100), ("boat", 70), ("bike", 40)]

df = pd.DataFrame(a, columns=("item", "price"))
print(df)
type(df)
# Out:
#    item  price
# 0   car    100
# 1  boat     70
# 2  bike     40
# pandas.core.frame.DataFrame

# %%
df.to_csv('df.csv', index=None)

# %%
#load

# %%
#save the dataframe to csv file
df.to_csv("item.csv", index =None)

# %%
#load the saved item dataset
df2 = pd.read_csv("item.csv")
df2
# Out:
#    item  price
# 0   car    100
# 1  boat     70
# 2  bike     40

# %%
#prove that the dataframe is made up of more than one series

df_price = df['price']
type(df_price)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Reading from files

# %%
#Loading the dataset #excel dataset
dataDf =pd.read_excel('Sample_Superstore.xlsx')

dataDf
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                     2     5.90    88525
# 1    2010-07-08     4.560000                     4    13.01    88522
# 2    2011-07-28   -47.640000                     7    49.92    88523
# 3    2011-07-28   -30.510000                     7    41.64    88523
# 4    2011-07-27   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421 2013-05-15   137.860000                    13   447.87    87532
# 9422 2013-05-14   -39.070000                     3    13.23    87532
# 9423 2013-09-14 -1225.029097                     4  2215.93    87533
# 9424 2010-02-11   349.485000                     5   506.50    87530
# 9425 2013-09-14    78.062400                    23   172.48    87533
#
# [9426 rows x 24 columns]

# %% [markdown]
# ## Writing to files

# %%
#saving the file to csv # use to_csv() and set index = False
data.to_csv("superstore.csv", index=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 #saving the file to csv # use to_csv() and set index = False
# ----> 2 data.to_csv("superstore.csv", index=None)
#
# NameError: name 'data' is not defined

# %%
datasv = pd.read_csv("superstore.csv")
datasv

# %% [markdown]
# ## Dataframe basics

# %%
#setting the default data view # pd.set_option("display.max_columns", 500)
pd.set_option("display.max_column", 200)

# %%
#display the data
dataDf
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies
# 4       Bonnie Potter     Express Air        Corporate       Technology
# ...               ...             ...              ...              ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture
# 9424    Tammy Buckley     Express Air         Consumer        Furniture
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies
#
#                Product Sub-Category Product Container  \
# 0                            Labels         Small Box
# 1               Pens & Art Supplies          Wrap Bag
# 2                             Paper         Small Box
# 3     Scissors, Rulers and Trimmers        Small Pack
# 4      Telephones and Communication         Small Box
# ...                             ...               ...
# 9421                      Envelopes         Small Box
# 9422            Pens & Art Supplies          Wrap Bag
# 9423                         Tables         Jumbo Box
# 9424             Office Furnishings        Medium Box
# 9425                      Envelopes         Small Box
#
#                                            Product Name  Product Base Margin  \
# 0                                              Avery 49                 0.36
# 1        SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                            Xerox 1968                 0.37
# 3              Acme® Preferred Stainless Steel Scissors                 0.56
# 4                                                   V70                 0.59
# ...                                                 ...                  ...
# 9421      Jet-Pak Recycled Peel 'N' Seal Padded Mailers                 0.40
# 9422       Eldon Spacemaker® Box, Quick-Snap Lid, Clear                 0.54
# 9423  Chromcraft Bull-Nose Wood Oval Conference Tabl...                 0.71
# 9424  Tenex 46" x 60" Computer Anti-Static Chairmat,...                 0.65
# 9425                      Staples #10 Colored Envelopes                 0.38
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales  Order ID
# 0    2012-05-30     1.320000                     2     5.90     88525
# 1    2010-07-08     4.560000                     4    13.01     88522
# 2    2011-07-28   -47.640000                     7    49.92     88523
# 3    2011-07-28   -30.510000                     7    41.64     88523
# 4    2011-07-27   998.202300                     8  1446.67     88523
# ...         ...          ...                   ...      ...       ...
# 9421 2013-05-15   137.860000                    13   447.87     87532
# 9422 2013-05-14   -39.070000                     3    13.23     87532
# 9423 2013-09-14 -1225.029097                     4  2215.93     87533
# 9424 2010-02-11   349.485000                     5   506.50     87530
# 9425 2013-09-14    78.062400                    23   172.48     87533
#
# [9426 rows x 24 columns]

# %% [markdown]
# ### Initial Exploratory Data analysis (IDA)

# %%
#checking a few top rows
dataDf.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies
# 4    Bonnie Potter  Express Air        Corporate       Technology
#
#             Product Sub-Category Product Container  \
# 0                         Labels         Small Box
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
#
#                                      Product Name  Product Base Margin  \
# 0                                        Avery 49                 0.36
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                      Xerox 1968                 0.37
# 3        Acme® Preferred Stainless Steel Scissors                 0.56
# 4                                             V70                 0.59
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales  Order ID
# 0    1.3200                     2     5.90     88525
# 1    4.5600                     4    13.01     88522
# 2  -47.6400                     7    49.92     88523
# 3  -30.5100                     7    41.64     88523
# 4  998.2023                     8  1446.67     88523

# %%
#Bottom 5 rows
dataDf.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#        Customer Name       Ship Mode Customer Segment Product Category  \
# 9421  Frederick Cole     Regular Air         Consumer  Office Supplies
# 9422  Frederick Cole     Regular Air         Consumer  Office Supplies
# 9423  Frederick Cole  Delivery Truck         Consumer        Furniture
# 9424   Tammy Buckley     Express Air         Consumer        Furniture
# 9425   Tammy Buckley     Express Air         Consumer  Office Supplies
#
#      Product Sub-Category Product Container  \
# 9421            Envelopes         Small Box
# 9422  Pens & Art Supplies          Wrap Bag
# 9423               Tables         Jumbo Box
# 9424   Office Furnishings        Medium Box
# 9425            Envelopes         Small Box
#
#                                            Product Name  Product Base Margin  \
# 9421      Jet-Pak Recycled Peel 'N' Seal Padded Mailers                 0.40
# 9422       Eldon Spacemaker® Box, Quick-Snap Lid, Clear                 0.54
# 9423  Chromcraft Bull-Nose Wood Oval Conference Tabl...                 0.71
# 9424  Tenex 46" x 60" Computer Anti-Static Chairmat,...                 0.65
# 9425                      Staples #10 Colored Envelopes                 0.38
#
#      Region State or Province        City  Postal Code Order Date  Ship Date  \
# 9421   East     West Virginia  Charleston        25314 2013-05-14 2013-05-15
# 9422   East     West Virginia  Charleston        25314 2013-05-14 2013-05-14
# 9423   East     West Virginia  Charleston        25314 2013-09-12 2013-09-14
# 9424   West           Wyoming    Cheyenne        82001 2010-02-08 2010-02-11
# 9425   West           Wyoming    Cheyenne        82001 2013-09-12 2013-09-14
#
#            Profit  Quantity ordered new    Sales  Order ID
# 9421   137.860000                    13   447.87     87532
# 9422   -39.070000                     3    13.23     87532
# 9423 -1225.029097                     4  2215.93     87533
# 9424   349.485000                     5   506.50     87530
# 9425    78.062400                    23   172.48     87533

# %%
#Displaying the top 3 rows #
dataDf.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies
#
#   Product Sub-Category Product Container  \
# 0               Labels         Small Box
# 1  Pens & Art Supplies          Wrap Bag
# 2                Paper         Small Box
#
#                                      Product Name  Product Base Margin  \
# 0                                        Avery 49                 0.36
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                      Xerox 1968                 0.37
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
#
#    Profit  Quantity ordered new  Sales  Order ID
# 0    1.32                     2   5.90     88525
# 1    4.56                     4  13.01     88522
# 2  -47.64                     7  49.92     88523

# %%
#Displaying the last 3 rows #
dataDf.tail(3)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#        Customer Name       Ship Mode Customer Segment Product Category  \
# 9423  Frederick Cole  Delivery Truck         Consumer        Furniture
# 9424   Tammy Buckley     Express Air         Consumer        Furniture
# 9425   Tammy Buckley     Express Air         Consumer  Office Supplies
#
#      Product Sub-Category Product Container  \
# 9423               Tables         Jumbo Box
# 9424   Office Furnishings        Medium Box
# 9425            Envelopes         Small Box
#
#                                            Product Name  Product Base Margin  \
# 9423  Chromcraft Bull-Nose Wood Oval Conference Tabl...                 0.71
# 9424  Tenex 46" x 60" Computer Anti-Static Chairmat,...                 0.65
# 9425                      Staples #10 Colored Envelopes                 0.38
#
#      Region State or Province        City  Postal Code Order Date  Ship Date  \
# 9423   East     West Virginia  Charleston        25314 2013-09-12 2013-09-14
# 9424   West           Wyoming    Cheyenne        82001 2010-02-08 2010-02-11
# 9425   West           Wyoming    Cheyenne        82001 2013-09-12 2013-09-14
#
#            Profit  Quantity ordered new    Sales  Order ID
# 9423 -1225.029097                     4  2215.93     87533
# 9424   349.485000                     5   506.50     87530
# 9425    78.062400                    23   172.48     87533

# %%
#Displaying 3 random rows #use sample()
dataDf.sample(4)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 7324    5602  Not Specified      0.06      328.14          91.05         2670
# 6072   24904  Not Specified      0.04       17.98           8.51         2228
# 3724   24257            Low      0.09        6.48           9.68         1409
# 3738   20626            Low      0.08       10.89           4.50         1411
#
#          Customer Name       Ship Mode Customer Segment Product Category  \
# 7324       Yvonne Mann  Delivery Truck      Home Office  Office Supplies
# 6072     Beverly Baker     Regular Air        Corporate       Technology
# 3724  Frederick Lehman     Express Air         Consumer  Office Supplies
# 3738        Larry Neal     Regular Air        Corporate  Office Supplies
#
#      Product Sub-Category Product Container  \
# 7324           Appliances        Jumbo Drum
# 6072      Office Machines        Medium Box
# 3724                Paper         Small Box
# 3738           Appliances         Small Box
#
#                                            Product Name  Product Base Margin  \
# 7324  Sanyo Counter Height Refrigerator with Crisper...                 0.57
# 6072            Canon P1-DHIII Palm Printing Calculator                 0.40
# 3724                                         Xerox 1993                 0.36
# 3738               Belkin 6 Outlet Metallic Surge Strip                 0.59
#
#      Region State or Province           City  Postal Code Order Date  \
# 7324   West        California    Los Angeles        90049 2013-06-08
# 6072   East      Pennsylvania         Radnor        19087 2011-07-03
# 3724   West              Utah  American Fork        84003 2013-06-03
# 3738   West        California    Morgan Hill        95037 2012-07-26
#
#       Ship Date    Profit  Quantity ordered new    Sales  Order ID
# 7324 2013-06-09 -473.6600                     3  1108.20     39686
# 6072 2011-07-04  -15.4164                     7   127.16     89156
# 3724 2013-06-10  -68.2320                     6    43.14     90448
# 3738 2012-07-30  -18.5000                     1    12.02     87093

# %%
#checking the columns # use columns attribute
dataDf.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#using list comprehesion
#Using list comprehnsion e.g [c for c in df.columns]
[c for c in dataDf.columns]
# Out:
# ['Row ID',
#  'Order Priority',
#  'Discount',
#  'Unit Price',
#  'Shipping Cost',
#  'Customer ID',
#  'Customer Name',
#  'Ship Mode',
#  'Customer Segment',
#  'Product Category',
#  'Product Sub-Category',
#  'Product Container',
#  'Product Name',
#  'Product Base Margin',
#  'Region',
#  'State or Province',
#  'City',
#  'Postal Code',
#  'Order Date',
#  'Ship Date',
#  'Profit',
#  'Quantity ordered new',
#  'Sales',
#  'Order ID']

# %%
#checking the index # use df.index
dataDf.index
# Out:
# RangeIndex(start=0, stop=9426, step=1)

# %%
#check the shape
dataDf.shape
# Out:
# (9426, 24)

# %%
#getting records
len(dataDf)
# Out:
# 9426

# %%
#check the shape
print(f" This dataset has {dataDf.shape[0]} records and {dataDf.shape[1]} columns")
# Out:
#  This dataset has 9426 records and 24 columns

# %% [markdown]
# ## Dataframe summary

# %%
#Checking the data Summary # use info(), we can also use info(verbose=False)
dataDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
#  15  State or Province     9426 non-null   object
#  16  City                  9426 non-null   object
#  17  Postal Code           9426 non-null   int64
#  18  Order Date            9426 non-null   datetime64[ns]
#  19  Ship Date             9426 non-null   datetime64[ns]
#  20  Profit                9426 non-null   float64
#  21  Quantity ordered new  9426 non-null   int64
#  22  Sales                 9426 non-null   float64
#  23  Order ID              9426 non-null   int64
# dtypes: datetime64[ns](2), float64(6), int64(5), object(11)
# memory usage: 1.7+ MB

# %%
# incoperating verbose argument
dataDf.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Columns: 24 entries, Row ID to Order ID
# dtypes: datetime64[ns](2), float64(6), int64(5), object(11)
# memory usage: 1.7+ MB

# %%
#Checking concise Descriptive statistics for numerical variables# use .describe
dataDf.describe().T
# Out:
#                        count                           mean  \
# Row ID                9426.0                   20241.015277
# Discount              9426.0                       0.049628
# Unit Price            9426.0                      88.303686
# Shipping Cost         9426.0                      12.795142
# Customer ID           9426.0                    1738.422236
# Product Base Margin   9354.0                       0.512189
# Postal Code           9426.0                   52446.327286
# Order Date              9426  2012-03-05 18:33:59.465308672
# Ship Date               9426  2012-03-07 19:16:18.485041408
# Profit                9426.0                      139.23641
# Quantity ordered new  9426.0                       13.79843
# Sales                 9426.0                     949.706272
# Order ID              9426.0                   82318.489073
#
#                                       min                  25%  \
# Row ID                                2.0             19330.25
# Discount                              0.0                 0.02
# Unit Price                           0.99                 6.48
# Shipping Cost                        0.49               3.1925
# Customer ID                           2.0                898.0
# Product Base Margin                  0.35                 0.38
# Postal Code                        1001.0              29406.0
# Order Date            2010-01-01 00:00:00  2011-03-07 06:00:00
# Ship Date             2010-01-02 00:00:00  2011-03-09 00:00:00
# Profit                         -16476.838           -74.017375
# Quantity ordered new                  1.0                  5.0
# Sales                                1.32              61.2825
# Order ID                              6.0             86737.25
#
#                                       50%                  75%  \
# Row ID                            21686.5             24042.75
# Discount                             0.05                 0.08
# Unit Price                          20.99                85.99
# Shipping Cost                        6.05                13.99
# Customer ID                        1750.0              2578.75
# Product Base Margin                  0.52                 0.59
# Postal Code                       52302.0              78516.0
# Order Date            2012-04-08 00:00:00  2013-03-26 00:00:00
# Ship Date             2012-04-09 00:00:00  2013-03-28 00:00:00
# Profit                             2.5676            140.24385
# Quantity ordered new                 10.0                 17.0
# Sales                             203.455             776.4025
# Order ID                          88344.5             89987.75
#
#                                       max           std
# Row ID                            26399.0   6101.890965
# Discount                             0.25      0.031798
# Unit Price                        6783.02    281.540982
# Shipping Cost                      164.73     17.181203
# Customer ID                        3403.0    979.167197
# Product Base Margin                  0.85      0.135229
# Postal Code                       99362.0  29374.597802
# Order Date            2013-12-31 00:00:00           NaN
# Ship Date             2014-01-17 00:00:00           NaN
# Profit                          16332.414    998.486483
# Quantity ordered new                170.0     15.107688
# Sales                           100119.16   2598.019818
# Order ID                          91591.0  19149.448857

# %%
#summary stst for numerical values
dataDf.describe(include = (["float", "int"]))
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          9354.000000   9426.000000   9426.000000           9426.000000
# mean              0.512189  52446.327286    139.236410             13.798430
# std               0.135229  29374.597802    998.486483             15.107688
# min               0.350000   1001.000000 -16476.838000              1.000000
# 25%               0.380000  29406.000000    -74.017375              5.000000
# 50%               0.520000  52302.000000      2.567600             10.000000
# 75%               0.590000  78516.000000    140.243850             17.000000
# max               0.850000  99362.000000  16332.414000            170.000000
#
#                Sales      Order ID
# count    9426.000000   9426.000000
# mean      949.706272  82318.489073
# std      2598.019818  19149.448857
# min         1.320000      6.000000
# 25%        61.282500  86737.250000
# 50%       203.455000  88344.500000
# 75%       776.402500  89987.750000
# max    100119.160000  91591.000000

# %%
#Checking concise Descriptive statistics for categorical variables# use coln.describe()
dataDf.describe(include = 'O').T  # you can use object
# Out:
#                      count unique                                        top  \
# Order Priority        9426      6                                       High
# Customer Name         9426   2703                              Louis Parrish
# Ship Mode             9426      3                                Regular Air
# Customer Segment      9426      4                                  Corporate
# Product Category      9426      3                            Office Supplies
# Product Sub-Category  9426     17                                      Paper
# Product Container     9426      7                                  Small Box
# Product Name          9426   1263  Global High-Back Leather Tilter, Burgundy
# Region                9426      4                                    Central
# State or Province     9426     49                                 California
# City                  9426   1424                              New York City
#
#                       freq
# Order Priority        1970
# Customer Name           27
# Ship Mode             7036
# Customer Segment      3375
# Product Category      5181
# Product Sub-Category  1379
# Product Container     4887
# Product Name            27
# Region                2899
# State or Province     1021
# City                   202

# %%
#another way of checking cat summary stst
dataDf.describe(include = 'object')  # you can use object
# Out:
#        Order Priority  Customer Name    Ship Mode Customer Segment  \
# count            9426           9426         9426             9426
# unique              6           2703            3                4
# top              High  Louis Parrish  Regular Air        Corporate
# freq             1970             27         7036             3375
#
#        Product Category Product Sub-Category Product Container  \
# count              9426                 9426              9426
# unique                3                   17                 7
# top     Office Supplies                Paper         Small Box
# freq               5181                 1379              4887
#
#                                      Product Name   Region State or Province  \
# count                                        9426     9426              9426
# unique                                       1263        4                49
# top     Global High-Back Leather Tilter, Burgundy  Central        California
# freq                                           27     2899              1021
#
#                  City
# count            9426
# unique           1424
# top     New York City
# freq              202

# %% [markdown]
# ## Subsetting Columns
#
# This is the act of selecting  a few columns from the entire dataframe.

# %%
#Selecting a single colung using [] make it a series
df_dscount = dataDf['Discount']
print(type(df_dscount))
df_dscount.head()
# Out:
# <class 'pandas.core.series.Series'>
# 0    0.01
# 1    0.01
# 2    0.03
# 3    0.01
# 4    0.00
# Name: Discount, dtype: float64

# %%
#selcting single column discount and making it a dataframe, use [[]]
df_dscount = dataDf[['Discount']]
print(type(df_dscount))
df_dscount.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Discount
# 0      0.01
# 1      0.01
# 2      0.03
# 3      0.01
# 4      0.00

# %%
#anaother way of selecting a single column without white space
df_dscount = dataDf.Discount
df_dscount
# Out:
# 0       0.01
# 1       0.01
# 2       0.03
# 3       0.01
# 4       0.00
#         ...
# 9421    0.06
# 9422    0.00
# 9423    0.08
# 9424    0.10
# 9425    0.09
# Name: Discount, Length: 9426, dtype: float64

# %%
dataDf.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#selcting the specific columns# use df[['col1', 'col2', 'col3']] e.g. selsct Order Date, Product Date, and ship mode
df_sub2 =dataDf[['Order Priority', 'Discount', 'Unit Price', 'Shipping Cost']]
df_sub2.head()
# Out:
#   Order Priority  Discount  Unit Price  Shipping Cost
# 0  Not Specified      0.01        2.88           0.50
# 1           High      0.01        2.84           0.93
# 2  Not Specified      0.03        6.68           6.15
# 3  Not Specified      0.01        5.68           3.60
# 4  Not Specified      0.00      205.99           2.50

# %%
# we can use slicing as well e.g. df[df.columns[:5]]
dataDf[dataDf.columns[4:11]]
# Out:
#       Shipping Cost  Customer ID    Customer Name       Ship Mode  \
# 0              0.50            2  Janice Fletcher     Regular Air
# 1              0.93            3    Bonnie Potter     Express Air
# 2              6.15            3    Bonnie Potter     Express Air
# 3              3.60            3    Bonnie Potter     Regular Air
# 4              2.50            3    Bonnie Potter     Express Air
# ...             ...          ...              ...             ...
# 9421          14.72         3402   Frederick Cole     Regular Air
# 9422           7.49         3402   Frederick Cole     Regular Air
# 9423          45.70         3402   Frederick Cole  Delivery Truck
# 9424          13.99         3403    Tammy Buckley     Express Air
# 9425           2.50         3403    Tammy Buckley     Express Air
#
#      Customer Segment Product Category           Product Sub-Category
# 0           Corporate  Office Supplies                         Labels
# 1           Corporate  Office Supplies            Pens & Art Supplies
# 2           Corporate  Office Supplies                          Paper
# 3           Corporate  Office Supplies  Scissors, Rulers and Trimmers
# 4           Corporate       Technology   Telephones and Communication
# ...               ...              ...                            ...
# 9421         Consumer  Office Supplies                      Envelopes
# 9422         Consumer  Office Supplies            Pens & Art Supplies
# 9423         Consumer        Furniture                         Tables
# 9424         Consumer        Furniture             Office Furnishings
# 9425         Consumer  Office Supplies                      Envelopes
#
# [9426 rows x 7 columns]

# %%
#Using list comprehnsion e.g df[[c for c in df.columns]] to preview the dataset
#dataDf[[c for c in dataDf.columns]]

# %% [markdown]
# ## Select dtypes

# %%
#checking the data type
dataDf.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
# Selecting the numerical variables use df.select_dtypes(), include what you want to select as an argument
# you can change int to object and rerun the code.

dataDf.select_dtypes("O")  # chnage "O" with "number" for numerical values
# Out:
#      Order Priority    Customer Name       Ship Mode Customer Segment  \
# 0     Not Specified  Janice Fletcher     Regular Air        Corporate
# 1              High    Bonnie Potter     Express Air        Corporate
# 2     Not Specified    Bonnie Potter     Express Air        Corporate
# 3     Not Specified    Bonnie Potter     Regular Air        Corporate
# 4     Not Specified    Bonnie Potter     Express Air        Corporate
# ...             ...              ...             ...              ...
# 9421       Critical   Frederick Cole     Regular Air         Consumer
# 9422       Critical   Frederick Cole     Regular Air         Consumer
# 9423  Not Specified   Frederick Cole  Delivery Truck         Consumer
# 9424           High    Tammy Buckley     Express Air         Consumer
# 9425  Not Specified    Tammy Buckley     Express Air         Consumer
#
#      Product Category           Product Sub-Category Product Container  \
# 0     Office Supplies                         Labels         Small Box
# 1     Office Supplies            Pens & Art Supplies          Wrap Bag
# 2     Office Supplies                          Paper         Small Box
# 3     Office Supplies  Scissors, Rulers and Trimmers        Small Pack
# 4          Technology   Telephones and Communication         Small Box
# ...               ...                            ...               ...
# 9421  Office Supplies                      Envelopes         Small Box
# 9422  Office Supplies            Pens & Art Supplies          Wrap Bag
# 9423        Furniture                         Tables         Jumbo Box
# 9424        Furniture             Office Furnishings        Medium Box
# 9425  Office Supplies                      Envelopes         Small Box
#
#                                            Product Name   Region  \
# 0                                              Avery 49  Central
# 1        SANFORD Liquid Accent™ Tank-Style Highlighters     West
# 2                                            Xerox 1968     West
# 3              Acme® Preferred Stainless Steel Scissors     West
# 4                                                   V70     West
# ...                                                 ...      ...
# 9421      Jet-Pak Recycled Peel 'N' Seal Padded Mailers     East
# 9422       Eldon Spacemaker® Box, Quick-Snap Lid, Clear     East
# 9423  Chromcraft Bull-Nose Wood Oval Conference Tabl...     East
# 9424  Tenex 46" x 60" Computer Anti-Static Chairmat,...     West
# 9425                      Staples #10 Colored Envelopes     West
#
#      State or Province        City
# 0             Illinois     Addison
# 1           Washington   Anacortes
# 2           Washington   Anacortes
# 3           Washington   Anacortes
# 4           Washington   Anacortes
# ...                ...         ...
# 9421     West Virginia  Charleston
# 9422     West Virginia  Charleston
# 9423     West Virginia  Charleston
# 9424           Wyoming    Cheyenne
# 9425           Wyoming    Cheyenne
#
# [9426 rows x 11 columns]

# %% [markdown]
# ## Select as series vs dataframe

# %%
#checking the series, use df['Col name']
dataDf["Discount"]
# Out:
# 0       0.01
# 1       0.01
# 2       0.03
# 3       0.01
# 4       0.00
#         ...
# 9421    0.06
# 9422    0.00
# 9423    0.08
# 9424    0.10
# 9425    0.09
# Name: Discount, Length: 9426, dtype: float64

# %%
#making the above as a dataframe , use df[['col name']]
dataDf[["Discount"]]
# Out:
#       Discount
# 0         0.01
# 1         0.01
# 2         0.03
# 3         0.01
# 4         0.00
# ...        ...
# 9421      0.06
# 9422      0.00
# 9423      0.08
# 9424      0.10
# 9425      0.09
#
# [9426 rows x 1 columns]

# %% [markdown]
# ## loc and iloc
#
# We can use loc(variable location), and iloc(index location) to access the variables as well

# %% [markdown]
# ### iloc

# %%
#checking the dataset
dataDf.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies
# 4    Bonnie Potter  Express Air        Corporate       Technology
#
#             Product Sub-Category Product Container  \
# 0                         Labels         Small Box
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
#
#                                      Product Name  Product Base Margin  \
# 0                                        Avery 49                 0.36
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                      Xerox 1968                 0.37
# 3        Acme® Preferred Stainless Steel Scissors                 0.56
# 4                                             V70                 0.59
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales  Order ID
# 0    1.3200                     2     5.90     88525
# 1    4.5600                     4    13.01     88522
# 2  -47.6400                     7    49.92     88523
# 3  -30.5100                     7    41.64     88523
# 4  998.2023                     8  1446.67     88523

# %%
# getting the value using iloc e.g df.iloc[1], getting one row and all columns
dataDf.iloc[1]
# Out:
# Row ID                                                           20847
# Order Priority                                                    High
# Discount                                                          0.01
# Unit Price                                                        2.84
# Shipping Cost                                                     0.93
# Customer ID                                                          3
# Customer Name                                            Bonnie Potter
# Ship Mode                                                  Express Air
# Customer Segment                                             Corporate
# Product Category                                       Office Supplies
# Product Sub-Category                               Pens & Art Supplies
# Product Container                                             Wrap Bag
# Product Name            SANFORD Liquid Accent™ Tank-Style Highlighters
# Product Base Margin                                               0.54
# Region                                                            West
# State or Province                                           Washington
# City                                                         Anacortes
# Postal Code                                                      98221
# Order Date                                         2010-07-07 00:00:00
# Ship Date                                          2010-07-08 00:00:00
# Profit                                                            4.56
# Quantity ordered new                                                 4
# Sales                                                            13.01
# Order ID                                                         88522
# Name: 1, dtype: object

# %%
#get value for row 1 and column 1
dataDf.iloc[2, 1]
# Out:
# 'Not Specified'

# %%
#slicing e.g df.iloc[:5, :5]
dataDf.iloc[:4, :4]
# Out:
#    Row ID Order Priority  Discount  Unit Price
# 0   18606  Not Specified      0.01        2.88
# 1   20847           High      0.01        2.84
# 2   23086  Not Specified      0.03        6.68
# 3   23087  Not Specified      0.01        5.68

# %%
list1 = [2,4,6,7,6]
list1[2:4]
# Out:
# [6, 7]

# %%
#get first 4 rows and column 2 and 7
dataDf.iloc[:4, [2, 7]]
# Out:
#    Discount    Ship Mode
# 0      0.01  Regular Air
# 1      0.01  Express Air
# 2      0.03  Express Air
# 3      0.01  Regular Air

# %%
# get row index 1 and 4, then column index 2 and 7
dataDf.iloc[[1,4], [2, 7]]
# Out:
#    Discount    Ship Mode
# 1      0.01  Express Air
# 4      0.00  Express Air

# %%
#Getting specific row e.g df.iloc[5], we can present our result in dataframe formart as well

# %%
#Checking the index 1 columns e.g df.iloc[:, 1]

# %%
#getting index 1 and 2 columns, e.g  df.iloc[:, [1, 2]]
dataDf.iloc[:, [1,6]]
# Out:
#      Order Priority    Customer Name
# 0     Not Specified  Janice Fletcher
# 1              High    Bonnie Potter
# 2     Not Specified    Bonnie Potter
# 3     Not Specified    Bonnie Potter
# 4     Not Specified    Bonnie Potter
# ...             ...              ...
# 9421       Critical   Frederick Cole
# 9422       Critical   Frederick Cole
# 9423  Not Specified   Frederick Cole
# 9424           High    Tammy Buckley
# 9425  Not Specified    Tammy Buckley
#
# [9426 rows x 2 columns]

# %% [markdown]
# Loc
#
# we use loc when we want to select the variable by the name

# %%
dataDf.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies
# 4    Bonnie Potter  Express Air        Corporate       Technology
#
#             Product Sub-Category Product Container  \
# 0                         Labels         Small Box
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
#
#                                      Product Name  Product Base Margin  \
# 0                                        Avery 49                 0.36
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                      Xerox 1968                 0.37
# 3        Acme® Preferred Stainless Steel Scissors                 0.56
# 4                                             V70                 0.59
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales  Order ID
# 0    1.3200                     2     5.90     88525
# 1    4.5600                     4    13.01     88522
# 2  -47.6400                     7    49.92     88523
# 3  -30.5100                     7    41.64     88523
# 4  998.2023                     8  1446.67     88523

# %%
dataDf.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#subsetting  2 columns df.loc[:, ['col1', 'col2']]
dataDf.loc[[2,5,7], ["Discount",'Ship Mode' ]]
# Out:
#    Discount       Ship Mode
# 2      0.03     Express Air
# 5      0.09     Express Air
# 7      0.02  Delivery Truck

# %%
#checking subclasses
x = dataDf['Customer Segment']
x.unique()
# Out:
# array(['Corporate', 'Home Office', 'Small Business', 'Consumer'],
#       dtype=object)

# %%
dataDf[17:20]
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 17   21776       Critical      0.06        9.48           7.29           11
# 18   23328           High      0.04       10.98           3.37           12
# 19   24844         Medium      0.09       78.69          19.99           14
#
#         Customer Name    Ship Mode Customer Segment Product Category  \
# 17      Marcus Dunlap  Regular Air      Home Office        Furniture
# 18          Kara Pace  Regular Air      Home Office  Office Supplies
# 19  Gwendolyn F Tyson  Regular Air   Small Business        Furniture
#
#              Product Sub-Category Product Container  \
# 17             Office Furnishings        Small Pack
# 18  Scissors, Rulers and Trimmers        Small Pack
# 19             Office Furnishings         Small Box
#
#                                          Product Name  Product Base Margin  \
# 17  DAX Two-Tone Rosewood/Black Document Frame, De...                 0.45
# 18                         Fiskars® Softgrip Scissors                 0.57
# 19  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...                 0.43
#
#      Region State or Province        City  Postal Code Order Date  Ship Date  \
# 17     East        New Jersey     Roselle         7203 2010-08-15 2010-08-17
# 18     East      Rhode Island    Cranston         2907 2012-02-24 2012-02-26
# 19  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-14
#
#       Profit  Quantity ordered new    Sales  Order ID
# 17  -53.8096                    22   211.15     90192
# 18   23.1200                     8    90.39     90196
# 19  803.4705                    16  1164.45     86838

# %%
dataDf.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#coverting column to index
detaind = dataDf.copy(deep=True)


#using index
detaind.index = dataind['Customer Name']
detaind.head()
# Out:
#                  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# Customer Name
# Janice Fletcher   18606  Not Specified      0.01        2.88           0.50
# Bonnie Potter     20847           High      0.01        2.84           0.93
# Bonnie Potter     23086  Not Specified      0.03        6.68           6.15
# Bonnie Potter     23087  Not Specified      0.01        5.68           3.60
# Bonnie Potter     23088  Not Specified      0.00      205.99           2.50
#
#                  Customer ID    Customer Name    Ship Mode Customer Segment  \
# Customer Name
# Janice Fletcher            2  Janice Fletcher  Regular Air        Corporate
# Bonnie Potter              3    Bonnie Potter  Express Air        Corporate
# Bonnie Potter              3    Bonnie Potter  Express Air        Corporate
# Bonnie Potter              3    Bonnie Potter  Regular Air        Corporate
# Bonnie Potter              3    Bonnie Potter  Express Air        Corporate
#
#                 Product Category           Product Sub-Category  \
# Customer Name
# Janice Fletcher  Office Supplies                         Labels
# Bonnie Potter    Office Supplies            Pens & Art Supplies
# Bonnie Potter    Office Supplies                          Paper
# Bonnie Potter    Office Supplies  Scissors, Rulers and Trimmers
# Bonnie Potter         Technology   Telephones and Communication
#
#                 Product Container  \
# Customer Name
# Janice Fletcher         Small Box
# Bonnie Potter            Wrap Bag
# Bonnie Potter           Small Box
# Bonnie Potter          Small Pack
# Bonnie Potter           Small Box
#
#                                                    Product Name  \
# Customer Name
# Janice Fletcher                                        Avery 49
# Bonnie Potter    SANFORD Liquid Accent™ Tank-Style Highlighters
# Bonnie Potter                                        Xerox 1968
# Bonnie Potter          Acme® Preferred Stainless Steel Scissors
# Bonnie Potter                                               V70
#
#                  Product Base Margin   Region State or Province       City  \
# Customer Name
# Janice Fletcher                 0.36  Central          Illinois    Addison
# Bonnie Potter                   0.54     West        Washington  Anacortes
# Bonnie Potter                   0.37     West        Washington  Anacortes
# Bonnie Potter                   0.56     West        Washington  Anacortes
# Bonnie Potter                   0.59     West        Washington  Anacortes
#
#                  Postal Code Order Date  Ship Date    Profit  \
# Customer Name
# Janice Fletcher        60101 2012-05-28 2012-05-30    1.3200
# Bonnie Potter          98221 2010-07-07 2010-07-08    4.5600
# Bonnie Potter          98221 2011-07-27 2011-07-28  -47.6400
# Bonnie Potter          98221 2011-07-27 2011-07-28  -30.5100
# Bonnie Potter          98221 2011-07-27 2011-07-27  998.2023
#
#                  Quantity ordered new    Sales  Order ID
# Customer Name
# Janice Fletcher                     2     5.90     88525
# Bonnie Potter                       4    13.01     88522
# Bonnie Potter                       7    49.92     88523
# Bonnie Potter                       7    41.64     88523
# Bonnie Potter                       8  1446.67     88523

# %% [markdown]
# #### loc filter expressions
#
# we can use loc filter to get specific records

# %%
data_sma["Customer Segment"].unique()
# Out:
# array(['Small Business'], dtype=object)

# %%
#Get the records of a specific value e.g  df.loc[df['Region'] == 'West']
data_sma = dataDf[dataDf['Customer Segment']== "Small Business"]
data_sma.head()
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 19   24844         Medium      0.09       78.69          19.99           14
# 20   24846         Medium      0.08        3.28           2.31           14
# 21   24847         Medium      0.05        3.28           4.20           14
# 22   24848         Medium      0.05        3.58           1.63           14
# 23   24845         Medium      0.01        6.48           7.86           14
#
#         Customer Name    Ship Mode Customer Segment Product Category  \
# 19  Gwendolyn F Tyson  Regular Air   Small Business        Furniture
# 20  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
# 21  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
# 22  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
# 23  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
#
#    Product Sub-Category Product Container  \
# 19   Office Furnishings         Small Box
# 20  Pens & Art Supplies          Wrap Bag
# 21  Pens & Art Supplies          Wrap Bag
# 22         Rubber Bands          Wrap Bag
# 23                Paper         Small Box
#
#                                          Product Name  Product Base Margin  \
# 19  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...                 0.43
# 20                                         Newell 321                 0.56
# 21                                         Newell 351                 0.56
# 22           OIC Colored Binder Clips, Assorted Sizes                 0.36
# 23                                          Xerox 213                 0.37
#
#      Region State or Province        City  Postal Code Order Date  Ship Date  \
# 19  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-14
# 20  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-13
# 21  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-13
# 22  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-13
# 23  Central         Minnesota  Prior Lake        55372 2013-05-12 2013-05-13
#
#       Profit  Quantity ordered new    Sales  Order ID
# 19  803.4705                    16  1164.45     86838
# 20  -24.0300                     7    22.23     86838
# 21  -37.0300                     4    13.99     86838
# 22   -0.7100                     4    14.26     86838
# 23  -44.5400                     4    29.55     86845

# %%
#using iloc
dataFun =dataDf[dataDf['Product Category']== "Furniture"]
dataFun
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 14     20876         Medium      0.08      140.98          36.09            8
# 15     20877         Medium      0.10      286.85          61.76            9
# 17     21776       Critical      0.06        9.48           7.29           11
# 19     24844         Medium      0.09       78.69          19.99           14
# ...      ...            ...       ...         ...            ...          ...
# 9408   22194           High      0.00      160.98          35.02         3398
# 9413   24911         Medium      0.10        9.38           4.93         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
#
#           Customer Name       Ship Mode Customer Segment Product Category  \
# 7        Ronnie Proctor  Delivery Truck      Home Office        Furniture
# 14       Melanie Garner  Delivery Truck      Home Office        Furniture
# 15     Lorraine Houston  Delivery Truck      Home Office        Furniture
# 17        Marcus Dunlap     Regular Air      Home Office        Furniture
# 19    Gwendolyn F Tyson     Regular Air   Small Business        Furniture
# ...                 ...             ...              ...              ...
# 9408      Marc McDaniel  Delivery Truck   Small Business        Furniture
# 9413      Florence Gold     Express Air   Small Business        Furniture
# 9420     Frederick Cole  Delivery Truck         Consumer        Furniture
# 9423     Frederick Cole  Delivery Truck         Consumer        Furniture
# 9424      Tammy Buckley     Express Air         Consumer        Furniture
#
#      Product Sub-Category Product Container  \
# 7      Chairs & Chairmats        Jumbo Drum
# 14              Bookcases         Jumbo Box
# 15                 Tables         Jumbo Box
# 17     Office Furnishings        Small Pack
# 19     Office Furnishings         Small Box
# ...                   ...               ...
# 9408            Bookcases         Jumbo Box
# 9413   Office Furnishings         Small Box
# 9420               Tables         Jumbo Box
# 9423               Tables         Jumbo Box
# 9424   Office Furnishings        Medium Box
#
#                                            Product Name  Product Base Margin  \
# 7        Global Troy™ Executive Leather Low-Back Tilter                 0.60
# 14     Sauder Forest Hills Library, Woodland Oak Finish                 0.77
# 15      Riverside Furniture Stanwyck Manor Table Series                 0.78
# 17    DAX Two-Tone Rosewood/Black Document Frame, De...                 0.45
# 19    Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...                 0.43
# ...                                                 ...                  ...
# 9408      Rush Hierlooms Collection Rich Wood Bookcases                 0.72
# 9413  Eldon Expressions Punched Metal & Wood Desk Ac...                 0.57
# 9420  Bush Advantage Collection® Round Conference Table                 0.64
# 9423  Chromcraft Bull-Nose Wood Oval Conference Tabl...                 0.71
# 9424  Tenex 46" x 60" Computer Anti-Static Chairmat,...                 0.65
#
#        Region State or Province         City  Postal Code Order Date  \
# 7        West        California  San Gabriel        91776 2010-12-13
# 14       East     New Hampshire      Bedford         3110 2012-12-25
# 15       East        New Jersey       Camden         8101 2012-12-25
# 17       East        New Jersey      Roselle         7203 2010-08-15
# 19    Central         Minnesota   Prior Lake        55372 2010-05-12
# ...       ...               ...          ...          ...        ...
# 9408  Central          Illinois      Decatur        62521 2012-11-25
# 9413     East     West Virginia     Fairmont        26554 2010-10-04
# 9420     East     West Virginia   Charleston        25314 2011-04-12
# 9423     East     West Virginia   Charleston        25314 2013-09-12
# 9424     West           Wyoming     Cheyenne        82001 2010-02-08
#
#       Ship Date       Profit  Quantity ordered new    Sales  Order ID
# 7    2010-12-15  4390.366500                    12  6362.85     90193
# 14   2012-12-26  -158.740000                     5   705.47     90199
# 15   2012-12-27  -346.615198                     8  1794.27     90199
# 17   2010-08-17   -53.809600                    22   211.15     90192
# 19   2010-05-14   803.470500                    16  1164.45     86838
# ...         ...          ...                   ...      ...       ...
# 9408 2012-11-26  1790.426000                    41  7158.10     87544
# 9413 2010-10-04   -24.710400                    15   135.78     87537
# 9420 2011-04-12  -513.790420                    10  1969.31     87531
# 9423 2013-09-14 -1225.029097                     4  2215.93     87533
# 9424 2010-02-11   349.485000                     5   506.50     87530
#
# [1933 rows x 24 columns]

# %%
#using loc
dataFun =dataDf.loc[dataDf['Product Category']== "Furniture"]
dataFun
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 14     20876         Medium      0.08      140.98          36.09            8
# 15     20877         Medium      0.10      286.85          61.76            9
# 17     21776       Critical      0.06        9.48           7.29           11
# 19     24844         Medium      0.09       78.69          19.99           14
# ...      ...            ...       ...         ...            ...          ...
# 9408   22194           High      0.00      160.98          35.02         3398
# 9413   24911         Medium      0.10        9.38           4.93         3400
# 9420   18329           High      0.08      212.60          52.20         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
#
#           Customer Name       Ship Mode Customer Segment Product Category  \
# 7        Ronnie Proctor  Delivery Truck      Home Office        Furniture
# 14       Melanie Garner  Delivery Truck      Home Office        Furniture
# 15     Lorraine Houston  Delivery Truck      Home Office        Furniture
# 17        Marcus Dunlap     Regular Air      Home Office        Furniture
# 19    Gwendolyn F Tyson     Regular Air   Small Business        Furniture
# ...                 ...             ...              ...              ...
# 9408      Marc McDaniel  Delivery Truck   Small Business        Furniture
# 9413      Florence Gold     Express Air   Small Business        Furniture
# 9420     Frederick Cole  Delivery Truck         Consumer        Furniture
# 9423     Frederick Cole  Delivery Truck         Consumer        Furniture
# 9424      Tammy Buckley     Express Air         Consumer        Furniture
#
#      Product Sub-Category Product Container  \
# 7      Chairs & Chairmats        Jumbo Drum
# 14              Bookcases         Jumbo Box
# 15                 Tables         Jumbo Box
# 17     Office Furnishings        Small Pack
# 19     Office Furnishings         Small Box
# ...                   ...               ...
# 9408            Bookcases         Jumbo Box
# 9413   Office Furnishings         Small Box
# 9420               Tables         Jumbo Box
# 9423               Tables         Jumbo Box
# 9424   Office Furnishings        Medium Box
#
#                                            Product Name  Product Base Margin  \
# 7        Global Troy™ Executive Leather Low-Back Tilter                 0.60
# 14     Sauder Forest Hills Library, Woodland Oak Finish                 0.77
# 15      Riverside Furniture Stanwyck Manor Table Series                 0.78
# 17    DAX Two-Tone Rosewood/Black Document Frame, De...                 0.45
# 19    Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...                 0.43
# ...                                                 ...                  ...
# 9408      Rush Hierlooms Collection Rich Wood Bookcases                 0.72
# 9413  Eldon Expressions Punched Metal & Wood Desk Ac...                 0.57
# 9420  Bush Advantage Collection® Round Conference Table                 0.64
# 9423  Chromcraft Bull-Nose Wood Oval Conference Tabl...                 0.71
# 9424  Tenex 46" x 60" Computer Anti-Static Chairmat,...                 0.65
#
#        Region State or Province         City  Postal Code Order Date  \
# 7        West        California  San Gabriel        91776 2010-12-13
# 14       East     New Hampshire      Bedford         3110 2012-12-25
# 15       East        New Jersey       Camden         8101 2012-12-25
# 17       East        New Jersey      Roselle         7203 2010-08-15
# 19    Central         Minnesota   Prior Lake        55372 2010-05-12
# ...       ...               ...          ...          ...        ...
# 9408  Central          Illinois      Decatur        62521 2012-11-25
# 9413     East     West Virginia     Fairmont        26554 2010-10-04
# 9420     East     West Virginia   Charleston        25314 2011-04-12
# 9423     East     West Virginia   Charleston        25314 2013-09-12
# 9424     West           Wyoming     Cheyenne        82001 2010-02-08
#
#       Ship Date       Profit  Quantity ordered new    Sales  Order ID
# 7    2010-12-15  4390.366500                    12  6362.85     90193
# 14   2012-12-26  -158.740000                     5   705.47     90199
# 15   2012-12-27  -346.615198                     8  1794.27     90199
# 17   2010-08-17   -53.809600                    22   211.15     90192
# 19   2010-05-14   803.470500                    16  1164.45     86838
# ...         ...          ...                   ...      ...       ...
# 9408 2012-11-26  1790.426000                    41  7158.10     87544
# 9413 2010-10-04   -24.710400                    15   135.78     87537
# 9420 2011-04-12  -513.790420                    10  1969.31     87531
# 9423 2013-09-14 -1225.029097                     4  2215.93     87533
# 9424 2010-02-11   349.485000                     5   506.50     87530
#
# [1933 rows x 24 columns]

# %%
#we can use loc to get records of more than one specific variables
#df.loc[(df['Product Category'] == 'Furniture') & (df['Order Date'] == '2010-07-07')]
dataDf.loc[(dataDf['Product Category'] == 'Furniture') & (dataDf['Order Date'] == '2010-07-07')]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1639   25539       Critical      0.03       14.20           5.30          619
# 4805   19419            Low      0.03        5.08           2.03         1781
# 8467   19739         Medium      0.00      137.48          32.18         3076
# 8492    1739         Medium      0.00      137.48          32.18         3079
#
#       Customer Name       Ship Mode Customer Segment Product Category  \
# 1639  Howard Rogers     Regular Air         Consumer        Furniture
# 4805   Jackie Capps     Regular Air      Home Office        Furniture
# 8467    Peter Hardy  Delivery Truck   Small Business        Furniture
# 8492  Andrew Levine  Delivery Truck   Small Business        Furniture
#
#      Product Sub-Category Product Container  \
# 1639   Office Furnishings          Wrap Bag
# 4805   Office Furnishings          Wrap Bag
# 8467            Bookcases         Jumbo Box
# 8492            Bookcases         Jumbo Box
#
#                                            Product Name  Product Base Margin  \
# 1639                             Coloredge Poster Frame                 0.46
# 4805                     Master Caster Door Stop, Brown                 0.51
# 8467  O'Sullivan Cherrywood Estates Traditional Barr...                 0.78
# 8492  O'Sullivan Cherrywood Estates Traditional Barr...                 0.78
#
#        Region State or Province          City  Postal Code Order Date  \
# 1639  Central          Michigan     Southgate        48195 2010-07-07
# 4805     West        California    San Carlos        94070 2010-07-07
# 8467     East              Ohio          Stow        44224 2010-07-07
# 8492     East      Pennsylvania  Philadelphia        19112 2010-07-07
#
#       Ship Date    Profit  Quantity ordered new    Sales  Order ID
# 1639 2010-07-08  107.0200                    14   205.98     88196
# 4805 2010-07-12   15.1524                     4    21.96     89858
# 8467 2010-07-08 -203.2700                     2   296.75     88241
# 8492 2010-07-08 -203.2700                    10  1483.76     12480

# %%
#we can use tilde(~) to get the records of those not represented in the code
#df.loc[~((df['Product Category'] == 'Furniture') & (df['Order Date'] == '2010-07-07'))]

# %% [markdown]
# ## query
#
# Query method is another way of getting specific records

# %%
# ?dataDf.query

# %%
#getting specific records e.g df.query('Sales >200 and Region == "West"')
dataDf.query('Sales < 300 and Region=="West"')
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 8      19483            Low      0.08        6.48           6.81            5
# 10     24563       Critical      0.07        6.48           6.60            6
# ...      ...            ...       ...         ...            ...          ...
# 9388   19722       Critical      0.02        5.98           5.35         3393
# 9389   21333            Low      0.10        6.68           6.92         3394
# 9390   23658         Medium      0.00       12.28           4.86         3394
# 9391   22578  Not Specified      0.04        6.84           8.37         3394
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#        Customer Name    Ship Mode Customer Segment Product Category  \
# 1      Bonnie Potter  Express Air        Corporate  Office Supplies
# 2      Bonnie Potter  Express Air        Corporate  Office Supplies
# 3      Bonnie Potter  Regular Air        Corporate  Office Supplies
# 8     Ronnie Proctor  Regular Air      Home Office  Office Supplies
# 10      Dwight Hwang  Regular Air      Home Office  Office Supplies
# ...              ...          ...              ...              ...
# 9388    Irene Murphy  Regular Air         Consumer  Office Supplies
# 9389   Julia Padgett  Regular Air         Consumer  Office Supplies
# 9390   Julia Padgett  Express Air         Consumer  Office Supplies
# 9391   Julia Padgett  Regular Air         Consumer  Office Supplies
# 9425   Tammy Buckley  Express Air         Consumer  Office Supplies
#
#                Product Sub-Category Product Container  \
# 1               Pens & Art Supplies          Wrap Bag
# 2                             Paper         Small Box
# 3     Scissors, Rulers and Trimmers        Small Pack
# 8                             Paper         Small Box
# 10                            Paper         Small Box
# ...                             ...               ...
# 9388                          Paper         Small Box
# 9389                          Paper         Small Box
# 9390                          Paper         Small Box
# 9391  Scissors, Rulers and Trimmers        Small Pack
# 9425                      Envelopes         Small Box
#
#                                            Product Name  Product Base Margin  \
# 1        SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                            Xerox 1968                 0.37
# 3              Acme® Preferred Stainless Steel Scissors                 0.56
# 8                                            Xerox 1930                 0.36
# 10                                             Xerox 21                 0.37
# ...                                                 ...                  ...
# 9388                                         Xerox 1947                 0.40
# 9389                                         Xerox 1898                 0.37
# 9390                                         Xerox 1933                 0.38
# 9391  Acme Design Line 8" Stainless Steel Bent Sciss...                 0.58
# 9425                      Staples #10 Colored Envelopes                 0.38
#
#      Region State or Province         City  Postal Code Order Date  Ship Date  \
# 1      West        Washington    Anacortes        98221 2010-07-07 2010-07-08
# 2      West        Washington    Anacortes        98221 2011-07-27 2011-07-28
# 3      West        Washington    Anacortes        98221 2011-07-27 2011-07-28
# 8      West        California  San Gabriel        91776 2012-05-12 2012-05-21
# 10     West        California     San Jose        95123 2012-12-29 2012-12-31
# ...     ...               ...          ...          ...        ...        ...
# 9388   West        Washington      Pullman        99163 2013-10-18 2013-10-21
# 9389   West        Washington     Puyallup        98373 2011-09-17 2011-09-24
# 9390   West        Washington     Puyallup        98373 2012-03-10 2012-03-11
# 9391   West        Washington     Puyallup        98373 2013-08-19 2013-08-20
# 9425   West           Wyoming     Cheyenne        82001 2013-09-12 2013-09-14
#
#          Profit  Quantity ordered new   Sales  Order ID
# 1       4.56000                     4   13.01     88522
# 2     -47.64000                     7   49.92     88523
# 3     -30.51000                     7   41.64     88523
# 8    -141.26000                    18  113.25     90197
# 10    -13.86000                     4   28.61     90200
# ...         ...                   ...     ...       ...
# 9388  -70.85000                    20  124.64     87914
# 9389  -74.03000                     9   57.22     87910
# 9390  115.21620                    13  166.98     87911
# 9391 -117.25296                    24  161.87     87913
# 9425   78.06240                    23  172.48     87533
#
# [1312 rows x 24 columns]

# %%
#Another different way of using query method
#min_sale = 600
#df.query('Sales > @min_sale and (Region == "West")')
#----------------------------------------------

# %% [markdown]
# ## Summary Statistics
#
# This is when we want to infer or get more information on the variable performance

# %%
#we can use min, max, mean, std, and quantile
print(dataDf.Sales.mean())
print(dataDf.Sales.min())
print(dataDf.Sales.max())
print(dataDf.Sales.std())
print(dataDf.Sales.quantile([.25, .5, .75]))
# Out:
# 949.7062720135795
# 1.32
# 100119.16
# 2598.0198182734284
# 0.25     61.2825
# 0.50    203.4550
# 0.75    776.4025
# Name: Sales, dtype: float64

# %% [markdown]
# ## agg
#
# This is used when we need to get summary statistics of more than 1 at ago.

# %%
# Getting  min, mean, max of 3 variables('Sales','Discount', 'Profit'), use  df[['col1','col2', 'col3']].agg(['mean', 'min', 'max'])
dataDf[['Sales','Discount', 'Profit']].agg(['mean', 'min', 'max'])
# Out:
#               Sales  Discount       Profit
# mean     949.706272  0.049628    139.23641
# min        1.320000  0.000000 -16476.83800
# max   100119.160000  0.250000  16332.41400

# %%
#another way of doing the above using key-value pair

# %% [markdown]
# ## Summarize categoricals
#
# we use different way to categorize categorical variables

# %%
## Summarize categoricals

#use unique to see the unique values in the variable region
dataDf['Product Category'].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
#nunique is used to get the number
dataDf['Product Category'].nunique()
# Out:
# 3

# %%
#Value count is used to get the number of occurances use df['col'].value_counts()
dataDf['Product Category'].value_counts()
# Out:
# Product Category
# Office Supplies    5181
# Technology         2312
# Furniture          1933
# Name: count, dtype: int64

# %%
# valuse counts for 2 variable, return dataframe  df[['col1', 'col2']].value_counts()

# %%
# we use reset index so that the result starts from index zero use df[['col1', 'col2']].value_counts().reset_index()
dataFun =dataDf.loc[dataDf['Product Category']== "Furniture"].reset_index()
dataFun
# Out:
#       index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0         7   20228  Not Specified      0.02      500.98          26.00
# 1        14   20876         Medium      0.08      140.98          36.09
# 2        15   20877         Medium      0.10      286.85          61.76
# 3        17   21776       Critical      0.06        9.48           7.29
# 4        19   24844         Medium      0.09       78.69          19.99
# ...     ...     ...            ...       ...         ...            ...
# 1928   9408   22194           High      0.00      160.98          35.02
# 1929   9413   24911         Medium      0.10        9.38           4.93
# 1930   9420   18329           High      0.08      212.60          52.20
# 1931   9423   24491  Not Specified      0.08      550.98          45.70
# 1932   9424   25914           High      0.10      105.98          13.99
#
#       Customer ID      Customer Name       Ship Mode Customer Segment  \
# 0               5     Ronnie Proctor  Delivery Truck      Home Office
# 1               8     Melanie Garner  Delivery Truck      Home Office
# 2               9   Lorraine Houston  Delivery Truck      Home Office
# 3              11      Marcus Dunlap     Regular Air      Home Office
# 4              14  Gwendolyn F Tyson     Regular Air   Small Business
# ...           ...                ...             ...              ...
# 1928         3398      Marc McDaniel  Delivery Truck   Small Business
# 1929         3400      Florence Gold     Express Air   Small Business
# 1930         3402     Frederick Cole  Delivery Truck         Consumer
# 1931         3402     Frederick Cole  Delivery Truck         Consumer
# 1932         3403      Tammy Buckley     Express Air         Consumer
#
#      Product Category Product Sub-Category Product Container  \
# 0           Furniture   Chairs & Chairmats        Jumbo Drum
# 1           Furniture            Bookcases         Jumbo Box
# 2           Furniture               Tables         Jumbo Box
# 3           Furniture   Office Furnishings        Small Pack
# 4           Furniture   Office Furnishings         Small Box
# ...               ...                  ...               ...
# 1928        Furniture            Bookcases         Jumbo Box
# 1929        Furniture   Office Furnishings         Small Box
# 1930        Furniture               Tables         Jumbo Box
# 1931        Furniture               Tables         Jumbo Box
# 1932        Furniture   Office Furnishings        Medium Box
#
#                                            Product Name  Product Base Margin  \
# 0        Global Troy™ Executive Leather Low-Back Tilter                 0.60
# 1      Sauder Forest Hills Library, Woodland Oak Finish                 0.77
# 2       Riverside Furniture Stanwyck Manor Table Series                 0.78
# 3     DAX Two-Tone Rosewood/Black Document Frame, De...                 0.45
# 4     Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...                 0.43
# ...                                                 ...                  ...
# 1928      Rush Hierlooms Collection Rich Wood Bookcases                 0.72
# 1929  Eldon Expressions Punched Metal & Wood Desk Ac...                 0.57
# 1930  Bush Advantage Collection® Round Conference Table                 0.64
# 1931  Chromcraft Bull-Nose Wood Oval Conference Tabl...                 0.71
# 1932  Tenex 46" x 60" Computer Anti-Static Chairmat,...                 0.65
#
#        Region State or Province         City  Postal Code Order Date  \
# 0        West        California  San Gabriel        91776 2010-12-13
# 1        East     New Hampshire      Bedford         3110 2012-12-25
# 2        East        New Jersey       Camden         8101 2012-12-25
# 3        East        New Jersey      Roselle         7203 2010-08-15
# 4     Central         Minnesota   Prior Lake        55372 2010-05-12
# ...       ...               ...          ...          ...        ...
# 1928  Central          Illinois      Decatur        62521 2012-11-25
# 1929     East     West Virginia     Fairmont        26554 2010-10-04
# 1930     East     West Virginia   Charleston        25314 2011-04-12
# 1931     East     West Virginia   Charleston        25314 2013-09-12
# 1932     West           Wyoming     Cheyenne        82001 2010-02-08
#
#       Ship Date       Profit  Quantity ordered new    Sales  Order ID
# 0    2010-12-15  4390.366500                    12  6362.85     90193
# 1    2012-12-26  -158.740000                     5   705.47     90199
# 2    2012-12-27  -346.615198                     8  1794.27     90199
# 3    2010-08-17   -53.809600                    22   211.15     90192
# 4    2010-05-14   803.470500                    16  1164.45     86838
# ...         ...          ...                   ...      ...       ...
# 1928 2012-11-26  1790.426000                    41  7158.10     87544
# 1929 2010-10-04   -24.710400                    15   135.78     87537
# 1930 2011-04-12  -513.790420                    10  1969.31     87531
# 1931 2013-09-14 -1225.029097                     4  2215.93     87533
# 1932 2010-02-11   349.485000                     5   506.50     87530
#
# [1933 rows x 25 columns]

# %% [markdown]
# ## shift, cumsum

# %%
#shift is commonly used in time series , use df[['col']].shift(1)

# %%
#shift last value df[['col']].shift(-1)

# %%
#shift last value df[['col']].shift(-1)

# %%
#summing up the sum values, use df[['col']].cumsum()

# %% [markdown]
# ## Rolling methods

# %%
#using Rolling, usse df[['col']].rolling(window=5).mean()

# %% [markdown]
# ## Groupby
#
# This is used when we want to summarize categorical features based on a certain numerical variable

# %%
# use groupby, use df.groupby('cat_col')[['num_coll']].mean(), e.g region and sales
dataDf.groupby("Region")[["Sales"]].mean()
# Out:
#                Sales
# Region
# Central   876.282035
# East     1058.455518
# South     817.475036
# West     1047.039755

# %%
#combining two numerical columns df.groupby('col1')[['col2', 'col3']].agg(["mean", "min"])

# %% [markdown]
# ## New columns

# %%
## New columns cost, by subtracting sales frm profit

dataDf["cost"] = dataDf["Sales"] - dataDf["Profit"]
dataDf.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies
# 4    Bonnie Potter  Express Air        Corporate       Technology
#
#             Product Sub-Category Product Container  \
# 0                         Labels         Small Box
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
#
#                                      Product Name  Product Base Margin  \
# 0                                        Avery 49                 0.36
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                      Xerox 1968                 0.37
# 3        Acme® Preferred Stainless Steel Scissors                 0.56
# 4                                             V70                 0.59
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales  Order ID      cost
# 0    1.3200                     2     5.90     88525    4.5800
# 1    4.5600                     4    13.01     88522    8.4500
# 2  -47.6400                     7    49.92     88523   97.5600
# 3  -30.5100                     7    41.64     88523   72.1500
# 4  998.2023                     8  1446.67     88523  448.4677

# %%
#Another way of creating new column using assign method, use df=df.assign(colname=expression)
#creating new column using .assign()   #df=df.assign(col_2=df["Profit"]/0.3)

# %% [markdown]
# ## Sorting
#
# This is a way of ordering the values either in ascending or descending order

# %%
#sort values use  df.sort_values('col'), we can apply argument ascending= False to get the result in descending order
#df.sort_values('Region', ascending=False)
dataf = dataDf.groupby("Region")[["Sales"]].mean()
dataf.sort_values('Sales', ascending=False)
# Out:
#                Sales
# Region
# East     1058.455518
# West     1047.039755
# Central   876.282035
# South     817.475036

# %%
#resetting the index, use df[['col1', 'col2', 'col3']].sort_values('col3', ascending=False).reset_index(drop=True)
#df[['Region',"Product Name","Sales"]].sort_values("Sales", ascending=False)

# %% [markdown]
# ## Missing data
#
# This is how we can check and fix null values

# %%
#fixing the null values  by dropping the rows df.dropna(subset=['col with missing value']), or just df.dropna() for entire dataframe
df.dropna(inplace=True)
df.isna().sum()

# %%
#filling up the missing value with specific value, use df[['col1', 'col2', 'col3']].fillna(0)

# %%
#Filling with the mean of the column, use df['col1'].fillna(df['col1'].mean())

# %% [markdown]
# ## Concat
#
# concat is used when all the variables as similar

# %%
# create 2 dataframe
#df1 = df.query('Region == "West"').copy()
#df2 = df.query('Region == "East"').copy()

# %%
#concat, use pd.concat([df1, df2])

# %%
#we can resset the index then concat as well
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# %%
#concat, use pd.concat([df1, df2], axis=1)
df_concat=pd.concat([df1,df2], axis=1)
df_concat.head()

# %% [markdown]
# ## Merge dataframes

# %%
#create 2 dataframe
df1 = df.groupby(['Region', 'Order Date'])[['Sales']].mean().reset_index()
df2 = df.groupby(['Region', 'Order Date'])[['Profit']].mean().reset_index()

# %%
## Merge dataframes#merge left, use df1.merge(df2, how="left")
df1.merge(df2,how='left')

# %%
#merge on right, use df1.merge(df2, how="right")

# %%
#merging on outer, use df1.merge(df2, how="outer")

# %% [markdown]
# ## Merge suffixes

# %%
#merging using suffices use, pd.merge(df1, df2, on=['col1', 'col2'])

# %%
#merge on specific similar column use pd.merge(df1, df2, on=df['col1'])

# %%
#merging using both letf and right on,use pd.merge(df1, df2, left_on=['col1'], right_on=['col1'])
