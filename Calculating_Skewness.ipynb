# %% [markdown]
# <a href="https://colab.research.google.com/github/joyangelai/Colabs/blob/main/Calculating_Skewness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import skew
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
# load iris dataset
iris = load_iris(as_frame=True)
df = iris.frame
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
# calculating skewness
skew_val = df.apply(skew)
skew_val
# Out:
# sepal length (cm)    0.311753
# sepal width (cm)     0.315767
# petal length (cm)   -0.272128
# petal width (cm)    -0.101934
# target               0.000000
# dtype: float64

# %%
# plotting the skewness
plt.figure(figsize=(10,6))
for column in df.columns[:-1]:
  sns.kdeplot(df[column], label=column)

plt.xlabel("Value")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')
